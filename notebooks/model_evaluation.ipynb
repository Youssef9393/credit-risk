# %%
"""
evaluate clustering models
"""

# %%
import joblib
from pathlib import Path

MODEL_DIR = Path(r"C:\Users\GK\OneDrive\Bureau\credit-risk-platform\models")

model = joblib.load(MODEL_DIR / "clustering_model.joblib")
scaler = joblib.load(MODEL_DIR / "clustering_scaler.joblib")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2129/444423215.py in <cell line: 0>()
#       4 MODEL_DIR = Path(r"C:\Users\GK\OneDrive\Bureau\credit-risk-platform\models")
#       5
# ----> 6 model = joblib.load(MODEL_DIR / "clustering_model.joblib")
#       7 scaler = joblib.load(MODEL_DIR / "clustering_scaler.joblib")
#
# /usr/local/lib/python3.12/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode, ensure_native_byte_order)
#     733             obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734     else:
# --> 735         with open(filename, "rb") as f:
#     736             with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737                 fobj,
#
# ...
